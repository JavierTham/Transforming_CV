# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import re
import os

from PIL import Image
import cv2

import torch
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Structured data

# %% [markdown]
# 1. clean dataset
# 2. extract the classes for each video
# 3. extract dominant action for each video

# %%
train_data = pd.read_csv("../data/Charades_v1_train.csv")
train_data
# Out:
#          id subject                                              scene  \
# 0     46GP8    HR43                                            Kitchen
# 1     N11GT    0KZ7                                             Stairs
# 2     0IH69    6RE8                                            Bedroom
# 3     KRF68    YA10                                       Laundry room
# 4     MJO7C    6RE8                                            Kitchen
# ...     ...     ...                                                ...
# 7980  7K2CS    HJZQ                                             Garage
# 7981  S2A89    KL48                                           Bathroom
# 7982  01O27    18IT                                           Bathroom
# 7983  2MJ72    6RE8                                            Bedroom
# 7984  PG1ID    D0RU  Home Office / Study (A room in a house used fo...
#
#       quality  relevance verified  \
# 0         6.0        7.0      Yes
# 1         6.0        7.0      Yes
# 2         6.0        5.0      Yes
# 3         6.0        7.0      Yes
# 4         6.0        6.0      Yes
# ...       ...        ...      ...
# 7980      6.0        6.0      Yes
# 7981      7.0        7.0      Yes
# 7982      6.0        7.0      Yes
# 7983      6.0        6.0      Yes
# 7984      6.0        6.0      Yes
#
#                                                  script  \
# 0     A person cooking on a stove while watching som...
# 1     One person opens up a folded blanket, then sne...
# 2     A person is seen leaving a cabinet. They then ...
# 3     A person runs into their laundry room. They gr...
# 4     A person runs into their pantry holding a bott...
# ...                                                 ...
# 7980  Person enters the garage while sneezing. Perso...
# 7981  A person takes a chair and walks it over, plac...
# 7982  A person enters a bathroom and closes the door...
# 7983  A person opens a window in their laundry room....
# 7984  A person snuggles with a laptop, A person sits...
#
#                                            objects  \
# 0                                food;stove;window
# 1                              blanket;broom;floor
# 2                           book;box;cabinet;shelf
# 3                               clothes;door;phone
# 4                                        cup;phone
# ...                                            ...
# 7980  chair;clothes;door;food;sandwich;shirt;spoon
# 7981                                    chair;door
# 7982                             door;floor;mirror
# 7983                             door;towel;window
# 7984                        broom;laptop;something
#
#                                            descriptions  \
# 0     A person cooks food on a stove before looking ...
# 1     Person at the bottom of the staircase shakes a...
# 2     A person is standing in a bedroom. They walk o...
# 3     A person runs in and shuts door. The person gr...
# 4     A person runs in place while holding a bottle ...
# ...                                                 ...
# 7980  A enters through a doorway, sneezes, then clos...
# 7981  A PERSON IS TAKING A CHAIR FROM ONE ROOM TO TH...
# 7982  A person is walking towards the bathroom. A pe...
# 7983  A person opens a window and looks out of it.  ...
# 7984                                                 {}
#
#                                                 actions  length
# 0                      c092 11.90 21.20;c147 0.00 12.60   24.83
# 1     c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2                                                   NaN   30.25
# 3     c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 4                       c015 0.00 32.00;c107 0.00 32.00   31.38
# ...                                                 ...     ...
# 7980  c065 17.60 31.00;c067 17.60 31.00;c153 0.00 5....   30.08
# 7981  c006 4.00 10.80;c141 4.40 10.90;c151 12.80 20....   19.29
# 7982  c006 5.10 11.50;c008 0.50 6.60;c124 39.00 47.0...   46.08
# 7983  c006 11.00 17.00;c037 20.70 31.00;c092 0.60 8....   30.25
# 7984  c047 0.00 33.00;c051 0.00 33.00;c052 0.00 33.0...   32.08
#
# [7985 rows x 11 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7985 entries, 0 to 7984
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            7985 non-null   object
#  1   subject       7985 non-null   object
#  2   scene         7985 non-null   object
#  3   quality       7968 non-null   float64
#  4   relevance     7930 non-null   float64
#  5   verified      7985 non-null   object
#  6   script        7985 non-null   object
#  7   objects       7982 non-null   object
#  8   descriptions  7985 non-null   object
#  9   actions       7811 non-null   object
#  10  length        7985 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 686.3+ KB

# %% [markdown]
# Remove all the rows that doesn't have a specified action

# %%
cleaned_data = train_data.dropna(subset = ['actions'])
cleaned_data.reset_index(drop = True, inplace = True)

# %%
cleaned_data.describe()
# Out:
#            quality    relevance       length
# count  7795.000000  7758.000000  7811.000000
# mean      5.585247     6.227636    29.885159
# std       1.186276     1.150637     9.406070
# min       1.000000     1.000000     2.330000
# 25%       5.000000     6.000000    26.960000
# 50%       6.000000     7.000000    30.540000
# 75%       6.000000     7.000000    32.120000
# max       7.000000     7.000000   194.330000

# %%
def extract_class(s):
    class_labels = re.findall('c\d+', s)
    return class_labels

# %%
extracted_classes = cleaned_data['actions'].apply(extract_class)
num_classes = extracted_classes.apply(len)

cleaned_data.loc[:, 'classes'] = extracted_classes
cleaned_data.loc[:, 'num_classes'] = num_classes

cleaned_data
# Out:
# /home/kayne/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
#          id subject                                              scene  \
# 0     46GP8    HR43                                            Kitchen
# 1     N11GT    0KZ7                                             Stairs
# 2     KRF68    YA10                                       Laundry room
# 3     MJO7C    6RE8                                            Kitchen
# 4     S6MPZ    EA2K  Home Office / Study (A room in a house used fo...
# ...     ...     ...                                                ...
# 7806  7K2CS    HJZQ                                             Garage
# 7807  S2A89    KL48                                           Bathroom
# 7808  01O27    18IT                                           Bathroom
# 7809  2MJ72    6RE8                                            Bedroom
# 7810  PG1ID    D0RU  Home Office / Study (A room in a house used fo...
#
#       quality  relevance verified  \
# 0         6.0        7.0      Yes
# 1         6.0        7.0      Yes
# 2         6.0        7.0      Yes
# 3         6.0        6.0      Yes
# 4         6.0        6.0      Yes
# ...       ...        ...      ...
# 7806      6.0        6.0      Yes
# 7807      7.0        7.0      Yes
# 7808      6.0        7.0      Yes
# 7809      6.0        6.0      Yes
# 7810      6.0        6.0      Yes
#
#                                                  script  \
# 0     A person cooking on a stove while watching som...
# 1     One person opens up a folded blanket, then sne...
# 2     A person runs into their laundry room. They gr...
# 3     A person runs into their pantry holding a bott...
# 4     A person is eating at the desk and lying the p...
# ...                                                 ...
# 7806  Person enters the garage while sneezing. Perso...
# 7807  A person takes a chair and walks it over, plac...
# 7808  A person enters a bathroom and closes the door...
# 7809  A person opens a window in their laundry room....
# 7810  A person snuggles with a laptop, A person sits...
#
#                                            objects  \
# 0                                food;stove;window
# 1                              blanket;broom;floor
# 2                               clothes;door;phone
# 3                                        cup;phone
# 4         chair;desk;food;phone;plate;snacks;table
# ...                                            ...
# 7806  chair;clothes;door;food;sandwich;shirt;spoon
# 7807                                    chair;door
# 7808                             door;floor;mirror
# 7809                             door;towel;window
# 7810                        broom;laptop;something
#
#                                            descriptions  \
# 0     A person cooks food on a stove before looking ...
# 1     Person at the bottom of the staircase shakes a...
# 2     A person runs in and shuts door. The person gr...
# 3     A person runs in place while holding a bottle ...
# 4     A person in a blue shirt is eating snacks off ...
# ...                                                 ...
# 7806  A enters through a doorway, sneezes, then clos...
# 7807  A PERSON IS TAKING A CHAIR FROM ONE ROOM TO TH...
# 7808  A person is walking towards the bathroom. A pe...
# 7809  A person opens a window and looks out of it.  ...
# 7810                                                 {}
#
#                                                 actions  length  \
# 0                      c092 11.90 21.20;c147 0.00 12.60   24.83
# 1     c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2     c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 3                       c015 0.00 32.00;c107 0.00 32.00   31.38
# 4     c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46
# ...                                                 ...     ...
# 7806  c065 17.60 31.00;c067 17.60 31.00;c153 0.00 5....   30.08
# 7807  c006 4.00 10.80;c141 4.40 10.90;c151 12.80 20....   19.29
# 7808  c006 5.10 11.50;c008 0.50 6.60;c124 39.00 47.0...   46.08
# 7809  c006 11.00 17.00;c037 20.70 31.00;c092 0.60 8....   30.25
# 7810  c047 0.00 33.00;c051 0.00 33.00;c052 0.00 33.0...   32.08
#
#                                                 classes  num_classes
# 0                                          [c092, c147]            2
# 1                              [c098, c075, c127, c153]            4
# 2            [c018, c141, c148, c006, c002, c150, c000]            7
# 3                                          [c015, c107]            2
# 4     [c009, c011, c015, c019, c156, c059, c061, c06...           10
# ...                                                 ...          ...
# 7806         [c065, c067, c153, c155, c097, c141, c156]            7
# 7807                           [c006, c141, c151, c097]            4
# 7808                           [c006, c008, c124, c096]            4
# 7809                           [c006, c037, c092, c033]            4
# 7810               [c047, c051, c052, c100, c151, c098]            6
#
# [7811 rows x 13 columns]

# %% [markdown]
# Some videos have more than 1 action/class, for the baseline model, we will just take the action that spans a longer duration.

# %%
def get_dominant_action(actions, classes):
    actions = actions.split(";")
    
    longest_duration = 0
    longest_action_idx = 0
    for i, action in enumerate(actions):
        start, end = set(map(float, action.split(" ")[1:]))
        duration = end - start
        if duration > longest_duration:
            longest_duration = duration
            longest_action_idx = i

    return classes[longest_action_idx]

# %%
cleaned_data['dominant_action'] = cleaned_data.apply(lambda x: get_dominant_action(x.actions, x.classes), axis = 1)
cleaned_data
# Out:
# /tmp/ipykernel_21992/4051372197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['dominant_action'] = cleaned_data.apply(lambda x: get_dominant_action(x.actions, x.classes), axis = 1)
#          id subject                                              scene  \
# 0     46GP8    HR43                                            Kitchen
# 1     N11GT    0KZ7                                             Stairs
# 2     KRF68    YA10                                       Laundry room
# 3     MJO7C    6RE8                                            Kitchen
# 4     S6MPZ    EA2K  Home Office / Study (A room in a house used fo...
# ...     ...     ...                                                ...
# 7806  7K2CS    HJZQ                                             Garage
# 7807  S2A89    KL48                                           Bathroom
# 7808  01O27    18IT                                           Bathroom
# 7809  2MJ72    6RE8                                            Bedroom
# 7810  PG1ID    D0RU  Home Office / Study (A room in a house used fo...
#
#       quality  relevance verified  \
# 0         6.0        7.0      Yes
# 1         6.0        7.0      Yes
# 2         6.0        7.0      Yes
# 3         6.0        6.0      Yes
# 4         6.0        6.0      Yes
# ...       ...        ...      ...
# 7806      6.0        6.0      Yes
# 7807      7.0        7.0      Yes
# 7808      6.0        7.0      Yes
# 7809      6.0        6.0      Yes
# 7810      6.0        6.0      Yes
#
#                                                  script  \
# 0     A person cooking on a stove while watching som...
# 1     One person opens up a folded blanket, then sne...
# 2     A person runs into their laundry room. They gr...
# 3     A person runs into their pantry holding a bott...
# 4     A person is eating at the desk and lying the p...
# ...                                                 ...
# 7806  Person enters the garage while sneezing. Perso...
# 7807  A person takes a chair and walks it over, plac...
# 7808  A person enters a bathroom and closes the door...
# 7809  A person opens a window in their laundry room....
# 7810  A person snuggles with a laptop, A person sits...
#
#                                            objects  \
# 0                                food;stove;window
# 1                              blanket;broom;floor
# 2                               clothes;door;phone
# 3                                        cup;phone
# 4         chair;desk;food;phone;plate;snacks;table
# ...                                            ...
# 7806  chair;clothes;door;food;sandwich;shirt;spoon
# 7807                                    chair;door
# 7808                             door;floor;mirror
# 7809                             door;towel;window
# 7810                        broom;laptop;something
#
#                                            descriptions  \
# 0     A person cooks food on a stove before looking ...
# 1     Person at the bottom of the staircase shakes a...
# 2     A person runs in and shuts door. The person gr...
# 3     A person runs in place while holding a bottle ...
# 4     A person in a blue shirt is eating snacks off ...
# ...                                                 ...
# 7806  A enters through a doorway, sneezes, then clos...
# 7807  A PERSON IS TAKING A CHAIR FROM ONE ROOM TO TH...
# 7808  A person is walking towards the bathroom. A pe...
# 7809  A person opens a window and looks out of it.  ...
# 7810                                                 {}
#
#                                                 actions  length  \
# 0                      c092 11.90 21.20;c147 0.00 12.60   24.83
# 1     c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2     c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 3                       c015 0.00 32.00;c107 0.00 32.00   31.38
# 4     c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46
# ...                                                 ...     ...
# 7806  c065 17.60 31.00;c067 17.60 31.00;c153 0.00 5....   30.08
# 7807  c006 4.00 10.80;c141 4.40 10.90;c151 12.80 20....   19.29
# 7808  c006 5.10 11.50;c008 0.50 6.60;c124 39.00 47.0...   46.08
# 7809  c006 11.00 17.00;c037 20.70 31.00;c092 0.60 8....   30.25
# 7810  c047 0.00 33.00;c051 0.00 33.00;c052 0.00 33.0...   32.08
#
#                                                 classes  num_classes  \
# 0                                          [c092, c147]            2
# 1                              [c098, c075, c127, c153]            4
# 2            [c018, c141, c148, c006, c002, c150, c000]            7
# 3                                          [c015, c107]            2
# 4     [c009, c011, c015, c019, c156, c059, c061, c06...           10
# ...                                                 ...          ...
# 7806         [c065, c067, c153, c155, c097, c141, c156]            7
# 7807                           [c006, c141, c151, c097]            4
# 7808                           [c006, c008, c124, c096]            4
# 7809                           [c006, c037, c092, c033]            4
# 7810               [c047, c051, c052, c100, c151, c098]            6
#
#      dominant_action
# 0               c147
# 1               c127
# 2               c150
# 3               c015
# 4               c011
# ...              ...
# 7806            c065
# 7807            c151
# 7808            c008
# 7809            c037
# 7810            c047
#
# [7811 rows x 14 columns]

# %%
classes = pd.read_csv("../data/classes/Charades_v1_classes.txt", header = None)
classes = classes[0].apply(lambda x: x.split(" ")[0])
classes
# Out:
# 0      c000
# 1      c001
# 2      c002
# 3      c003
# 4      c004
#        ...
# 152    c152
# 153    c153
# 154    c154
# 155    c155
# 156    c156
# Name: 0, Length: 157, dtype: object

# %%
le = LabelEncoder()
le.fit(classes)
vid_classes = le.transform(cleaned_data['dominant_action'])

# %%
cleaned_data['vid_class'] = vid_classes
cleaned_data.head()
# Out:
# /tmp/ipykernel_21992/2359335719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['vid_class'] = vid_classes
#       id subject                                              scene  quality  \
# 0  46GP8    HR43                                            Kitchen      6.0
# 1  N11GT    0KZ7                                             Stairs      6.0
# 2  KRF68    YA10                                       Laundry room      6.0
# 3  MJO7C    6RE8                                            Kitchen      6.0
# 4  S6MPZ    EA2K  Home Office / Study (A room in a house used fo...      6.0
#
#    relevance verified                                             script  \
# 0        7.0      Yes  A person cooking on a stove while watching som...
# 1        7.0      Yes  One person opens up a folded blanket, then sne...
# 2        7.0      Yes  A person runs into their laundry room. They gr...
# 3        6.0      Yes  A person runs into their pantry holding a bott...
# 4        6.0      Yes  A person is eating at the desk and lying the p...
#
#                                     objects  \
# 0                         food;stove;window
# 1                       blanket;broom;floor
# 2                        clothes;door;phone
# 3                                 cup;phone
# 4  chair;desk;food;phone;plate;snacks;table
#
#                                         descriptions  \
# 0  A person cooks food on a stove before looking ...
# 1  Person at the bottom of the staircase shakes a...
# 2  A person runs in and shuts door. The person gr...
# 3  A person runs in place while holding a bottle ...
# 4  A person in a blue shirt is eating snacks off ...
#
#                                              actions  length  \
# 0                   c092 11.90 21.20;c147 0.00 12.60   24.83
# 1  c098 8.60 14.20;c075 0.00 11.70;c127 0.00 15.2...   18.33
# 2  c018 22.60 27.80;c141 4.10 9.60;c148 10.30 25....   30.33
# 3                    c015 0.00 32.00;c107 0.00 32.00   31.38
# 4  c009 0.00 4.30;c011 0.00 39.00;c015 0.00 39.00...   38.46
#
#                                              classes  num_classes  \
# 0                                       [c092, c147]            2
# 1                           [c098, c075, c127, c153]            4
# 2         [c018, c141, c148, c006, c002, c150, c000]            7
# 3                                       [c015, c107]            2
# 4  [c009, c011, c015, c019, c156, c059, c061, c06...           10
#
#   dominant_action  vid_class
# 0            c147        147
# 1            c127        127
# 2            c150        150
# 3            c015         15
# 4            c011         11

# %%
cleaned_data.to_csv("../data/train_data.csv", index = False)

# %% [markdown]
# ### Test data

# %%
test_data = pd.read_csv("../data/Charades_v1_test.csv")
test_data.head()
# Out:
#       id subject                                              scene  quality  \
# 0  YSKX3    CP6Y                                            Bedroom      5.0
# 1  T5ECU    M7K8                                        Living room      6.0
# 2  AAH6R    ENHU             Closet / Walk-in closet / Spear closet      6.0
# 3  015XE    GFWE                                            Kitchen      6.0
# 4  TJZ0P    ENHU  Home Office / Study (A room in a house used fo...      5.0
#
#    relevance verified                                             script  \
# 0        6.0      Yes   A person fixes the bed then throws pillow on it.
# 1        7.0      Yes  One person is smiling and drinking while watch...
# 2        6.0      Yes  A person undressing in the doorway walks to a ...
# 3        5.0      Yes  A person is taking a picture of a light while ...
# 4        7.0      Yes  A person in their home office opening a book t...
#
#                                            objects  \
# 0                      bed;blanket;mattress;pillow
# 1                 chair;cup;dish;dog;vacuum;window
# 2                     chair;clothes;doorway;mirror
# 3                       camera;light;phone;picture
# 4  arm;book;chair;food;sandwich;shelf;table;window
#
#                                         descriptions  \
# 0  A person looks under a mattress and pats the b...
# 1  A person leaves the room holding an umbrella w...
# 2  A person is looking in the mirror, adjusting h...
# 3  A person holds a camera up to a light on the c...
# 4  A person sitting down picks up a book. A perso...
#
#                                              actions  length
# 0  c077 12.10 18.00;c079 11.80 17.30;c080 13.00 1...   16.62
# 1  c137 0.30 9.00;c092 0.00 18.90;c152 3.50 31.00...   31.29
# 2  c059 3.50 8.00;c151 3.00 7.60;c148 0.00 8.00;c...    7.38
# 3  c015 0.00 32.10;c087 0.60 32.10;c016 0.00 32.1...   32.83
# 4  c067 8.60 13.80;c028 6.90 11.90;c059 0.00 19.0...   17.71

# %%
test_data = test_data.dropna(subset = ['actions'])
test_data.reset_index(drop = True, inplace = True)

# %%
extracted_classes_test = test_data['actions'].apply(extract_class)
num_classes_test = extracted_classes_test.apply(len)

test_data.loc[:, 'classes'] = extracted_classes_test
test_data.loc[:, 'num_classes'] = num_classes_test
test_data['dominant_action'] = test_data.apply(lambda x: get_dominant_action(x.actions, x.classes), axis = 1)

vid_classes_test = le.transform(test_data['dominant_action'])
test_data['vid_class'] = vid_classes_test

test_data.head()
# Out:
#       id subject                                              scene  quality  \
# 0  YSKX3    CP6Y                                            Bedroom      5.0
# 1  T5ECU    M7K8                                        Living room      6.0
# 2  AAH6R    ENHU             Closet / Walk-in closet / Spear closet      6.0
# 3  015XE    GFWE                                            Kitchen      6.0
# 4  TJZ0P    ENHU  Home Office / Study (A room in a house used fo...      5.0
#
#    relevance verified                                             script  \
# 0        6.0      Yes   A person fixes the bed then throws pillow on it.
# 1        7.0      Yes  One person is smiling and drinking while watch...
# 2        6.0      Yes  A person undressing in the doorway walks to a ...
# 3        5.0      Yes  A person is taking a picture of a light while ...
# 4        7.0      Yes  A person in their home office opening a book t...
#
#                                            objects  \
# 0                      bed;blanket;mattress;pillow
# 1                 chair;cup;dish;dog;vacuum;window
# 2                     chair;clothes;doorway;mirror
# 3                       camera;light;phone;picture
# 4  arm;book;chair;food;sandwich;shelf;table;window
#
#                                         descriptions  \
# 0  A person looks under a mattress and pats the b...
# 1  A person leaves the room holding an umbrella w...
# 2  A person is looking in the mirror, adjusting h...
# 3  A person holds a camera up to a light on the c...
# 4  A person sitting down picks up a book. A perso...
#
#                                              actions  length  \
# 0  c077 12.10 18.00;c079 11.80 17.30;c080 13.00 1...   16.62
# 1  c137 0.30 9.00;c092 0.00 18.90;c152 3.50 31.00...   31.29
# 2  c059 3.50 8.00;c151 3.00 7.60;c148 0.00 8.00;c...    7.38
# 3  c015 0.00 32.10;c087 0.60 32.10;c016 0.00 32.1...   32.83
# 4  c067 8.60 13.80;c028 6.90 11.90;c059 0.00 19.0...   17.71
#
#                                              classes  num_classes  \
# 0                     [c077, c079, c080, c076, c075]            5
# 1  [c137, c092, c152, c154, c059, c118, c151, c10...           14
# 2                     [c059, c151, c148, c096, c155]            5
# 3                           [c015, c087, c016, c154]            4
# 4  [c067, c028, c059, c065, c068, c026, c153, c01...           23
#
#   dominant_action  vid_class
# 0            c075         75
# 1            c059         59
# 2            c148        148
# 3            c015         15
# 4            c059         59

# %%
test_data.to_csv("../data/test_data.csv", index = False)
